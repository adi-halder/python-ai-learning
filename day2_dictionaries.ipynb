# %% [markdown]
# <a href="https://colab.research.google.com/github/adi-halder/python-ai-learning/blob/main/day2_dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mini Project - Student Report Card
student = {
    "name": "Aditya Halder",
    "roll": 42,
    "marks": {
        "Maths": 91,
        "Physics":92,
        "Python": 78,
        "Chemistry": 88,
  }
}
print("===== REPORT CARD =====")
print("Name:", student["name"])
print("Roll No:", student["roll"])
print("----------------------")

for subject, mark in student["marks"].items():
  if mark >= 90:
    print(subject, "->", mark, "Excellent")
  else:
    print(subject, "->", mark, "Good")

    print("-----------------------")
    marks_list = list(student["marks"].values())
    print("Total:", sum(marks_list))
    print("Average:", sum(marks_list) / len(marks_list))
    print("Highest:", max(marks_list))
    print("Lowest:", min(marks_list))
    print("=========================")
# Out:
# ===== REPORT CARD =====
# Name: Aditya Halder
# Roll No: 42
# ----------------------
# Maths -> 91 Excellent
# Physics -> 92 Excellent
# Python -> 78 Good
# -----------------------
# Total: 349
# Average: 87.25
# Highest: 92
# Lowest: 78
# ...
# Chemistry -> 88 Good
# -----------------------
# Total: 349
# Average: 87.25
# Highest: 92
# Lowest: 78
# ...
